# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Demographic Data Processing

# %%
def remove_minus(x):
    if (x == "-"):
        return "NaN"
    else:
        return x.replace("-", "").replace("+", "").replace(",", "")

# %%
#this data is for 11 variables, all census tracts in California, using ACS 2009 5YR estimates 

demog_data_path = '/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/demographic_data/'
#get percentages of each race

race = pd.read_csv(demog_data_path+ 'ACS_09_5YR_B03002_race_clean.csv')
race["Percent NH White alone"] = race["Estimate; Not Hispanic or Latino: - White alone"]/race["Estimate; Total:"]
race["Percent NH Black or African African alone"] = race["Estimate; Not Hispanic or Latino: - Black or African American alone"]/race["Estimate; Total:"]
race["Percent NH Asian alone"] = race["Estimate; Not Hispanic or Latino: - Asian alone"]/race["Estimate; Total:"]
race["Percent Hispanic"] = race["Estimate; Hispanic or Latino:"]/race["Estimate; Total:"]


edu = pd.read_csv(demog_data_path+ 'ACS_09_5YR_S1501_bach_clean.csv')
edu = edu.rename({"Percent of population 25 years and over  with Bachelor\'s degree": "Percent of population 25 years and over with Bachelor\'s degree"}, axis=1)
edu["Percent of population 25 years and over with Bachelor\'s degree"] = edu["Percent of population 25 years and over with Bachelor\'s degree"].apply(lambda x: x.replace("+", "").replace("-", "NaN"))
edu["Percent of population 25 years and over with Bachelor\'s degree"] = edu["Percent of population 25 years and over with Bachelor\'s degree"].astype(float).dropna()


#get rid of + and ***
hvalue = pd.read_csv(demog_data_path+ 'ACS_09_5YR_B25077_hvalue_clean.csv')
hvalue["Estimate; Median value (dollars)"] = hvalue["Estimate; Median value (dollars)"].apply(lambda x: x.replace("+", "").replace("-", "NaN").replace(",", ""))
hvalue["Estimate; Median value (dollars)"] = hvalue["Estimate; Median value (dollars)"].astype(float)

#hvalue["Estimate; Median value (dollars)"] = hvalue["Estimate; Median value (dollars)"].astype(float).dropna()

#add attached and detached and find the %
single = pd.read_csv(demog_data_path+ 'ACS_09_5YR_B25024_singlefam_clean.csv')
single["Total Single Family"] = single["Estimate; 1, attached"]+ single["Estimate; 1, detached"]
single["% Single Family"] = single["Total Single Family"] / single["Estimate; Total:"]
#single["Tract"] = (single["Id2"].astype(str)).apply(lambda x: int(x[4:8]))

poverty = pd.read_csv(demog_data_path+"ACS_09_5YR_S1702_povertyfam_clean.csv")

# poverty = pd.read_csv(demog_data_path+ "ACS_17_5YR_S1701_poverty_clean.csv")
poverty['All families - Percent  below poverty level; Estimate; Families'] = poverty['All families - Percent  below poverty level; Estimate; Families'].apply(lambda x: x.replace("+", "").replace("-", "NaN"))
poverty['All families - Percent  below poverty level; Estimate; Families'] = poverty['All families - Percent  below poverty level; Estimate; Families'].astype(float).dropna()



units = pd.read_csv(demog_data_path+'ACS_09_5YR_B25001_units_clean.csv')
#units["Tract"] = (units["Id2"].astype(str)).apply(lambda x: int(x[4:8]))


#find % renter occupied
tenure = pd.read_csv(demog_data_path+ 'ACS_09_5YR_B25003_tenure_clean.csv')
tenure["% Renter Occupied"] = tenure["Estimate; Renter occupied"]/tenure["Estimate; Total:"]
tenure["% Owner Occupied"] = tenure["Estimate; Owner occupied"]/tenure["Estimate; Total:"]


income = pd.read_csv(demog_data_path + 'ACS_09_5YR_S1903_income.csv')
income["Median income (dollars); All households"] = income["Median income (dollars); All households"].apply(remove_minus)

income["Median income (dollars); All households"] = income["Median income (dollars); All households"].astype(float)

# %% [markdown]
# #### Create Controlled features dataframe

# %%
race_units_merged = race.merge(units, how='left', left_on="Id2", right_on="Id2")
print("race and units merged", "length", len(race_units_merged))
#print("race and units merged", "dtypes", race_units_merged.dtypes)

edu_merged = race_units_merged.merge(edu, how='left', left_on="Id2", right_on="Id2")
print("edu merged", "length", len(edu_merged))
#print("edu merged", "dtypes", edu_merged.dtypes)

income_merged = edu_merged.merge(income, how='left', left_on="Id2", right_on="Id2")
print("income merged", "length", len(income_merged))
#print("income", "dtypes", income_merged.dtypes)

poverty_merged = income_merged.merge(poverty, how='left', left_on="Id2", right_on="Id2")
print("poverty merged", "length", len(poverty_merged))
#print("poverty", "dtypes", poverty_merged.dtypes)

hvalue_merged = poverty_merged.merge(hvalue, how='left', left_on="Id2", right_on="Id2")
print("hvalue merged", "length", len(hvalue_merged))
#print("hvalue", "dtypes", hvalue_merged.dtypes)

single_merged = hvalue_merged.merge(single, how='left', left_on="Id2", right_on="Id2")
print("single merged", "length", len(single_merged))
#print("singe merged", "dtypes", single_merged.dtypes)


merged = single_merged.merge(tenure, how='left', left_on="Id2", right_on="Id2")
print("tenure merged", "length", len(merged))
merged.head(20)
# Out:
# race and units merged length 7049
# edu merged length 7049
# income merged length 7049
# poverty merged length 7049
# hvalue merged length 7049
# single merged length 7049
# tenure merged length 7049
#            Id2                                    Geography_x  \
# 0   6001400100  Census Tract 4001, Alameda County, California
# 1   6001400200  Census Tract 4002, Alameda County, California
# 2   6001400300  Census Tract 4003, Alameda County, California
# 3   6001400400  Census Tract 4004, Alameda County, California
# 4   6001400500  Census Tract 4005, Alameda County, California
# 5   6001400600  Census Tract 4006, Alameda County, California
# 6   6001400700  Census Tract 4007, Alameda County, California
# 7   6001400800  Census Tract 4008, Alameda County, California
# 8   6001400900  Census Tract 4009, Alameda County, California
# 9   6001401000  Census Tract 4010, Alameda County, California
# 10  6001401100  Census Tract 4011, Alameda County, California
# 11  6001401200  Census Tract 4012, Alameda County, California
# 12  6001401300  Census Tract 4013, Alameda County, California
# 13  6001401400  Census Tract 4014, Alameda County, California
# 14  6001401500  Census Tract 4015, Alameda County, California
# 15  6001401600  Census Tract 4016, Alameda County, California
# 16  6001401700  Census Tract 4017, Alameda County, California
# 17  6001401800  Census Tract 4018, Alameda County, California
# 18  6001401900  Census Tract 4019, Alameda County, California
# 19  6001402000  Census Tract 4020, Alameda County, California
#
#     Estimate; Total:_x  Margin of Error; Total:_x  \
# 0                 2872                        233
# 1                 2076                        165
# 2                 4964                        369
# 3                 4223                        553
# 4                 3759                        308
# 5                 1676                        200
# 6                 3901                        548
# 7                 3005                        335
# 8                 2667                        392
# 9                 6152                        727
# 10                3551                        362
# 11                2515                        263
# 12                3269                        614
# 13                3536                        785
# 14                2493                        465
# 15                1614                        417
# 16                1875                        601
# 17                1265                        325
# 18                 678                        341
# 19                  87                         69
#
#     Estimate; Not Hispanic or Latino:  \
# 0                                2851
# 1                                1854
# 2                                4541
# 3                                3957
# 4                                3323
# 5                                1576
# 6                                3709
# 7                                2746
# 8                                2557
# 9                                5714
# 10                               2936
# 11                               2368
# 12                               2722
# 13                               2880
# 14                               2226
# 15                               1446
# 16                               1078
# 17                               1082
# 18                                311
# 19                                 21
#
#     Estimate; Not Hispanic or Latino: - White alone  \
# 0                                              2209
# 1                                              1594
# 2                                              3545
# 3                                              2948
# 4                                              1577
# 5                                               567
# 6                                              1392
# 7                                               982
# 8                                              1004
# 9                                              1026
# 10                                             1856
# 11                                             1692
# 12                                              727
# 13                                              279
# 14                                              245
# 15                                               78
# 16                                              249
# 17                                              143
# 18                                              115
# 19                                                0
#
#     Estimate; Not Hispanic or Latino: - Black or African American alone  \
# 0                                                 119
# 1                                                  47
# 2                                                 492
# 3                                                 391
# 4                                                1303
# 5                                                 793
# 6                                                1771
# 7                                                1138
# 8                                                1454
# 9                                                3484
# 10                                                498
# 11                                                349
# 12                                               1369
# 13                                               1770
# 14                                               1587
# 15                                                944
# 16                                                597
# 17                                                825
# 18                                                 19
# 19                                                 21
#
#     Estimate; Not Hispanic or Latino: - Asian alone  \
# 0                                               318
# 1                                               144
# 2                                               375
# 3                                               330
# 4                                               249
# 5                                                54
# 6                                               371
# 7                                               525
# 8                                                20
# 9                                               881
# 10                                              392
# 11                                              292
# 12                                              542
# 13                                              699
# 14                                              251
# 15                                              291
# 16                                              131
# 17                                              100
# 18                                               74
# 19                                                0
#
#     Estimate; Hispanic or Latino:  \
# 0                              21
# 1                             222
# 2                             423
# 3                             266
# 4                             436
# 5                             100
# 6                             192
# 7                             259
# 8                             110
# 9                             438
# 10                            615
# 11                            147
# 12                            547
# 13                            656
# 14                            267
# 15                            168
# 16                            797
# 17                            183
# 18                            367
# 19                             66
#
#     Estimate; Hispanic or Latino: - White alone        ...         \
# 0                                            15        ...
# 1                                            56        ...
# 2                                           247        ...
# 3                                           149        ...
# 4                                           179        ...
# 5                                            75        ...
# 6                                            32        ...
# 7                                            67        ...
# 8                                            99        ...
# 9                                           402        ...
# 10                                          431        ...
# 11                                          103        ...
# 12                                          382        ...
# 13                                          207        ...
# 14                                          197        ...
# 15                                           68        ...
# 16                                          201        ...
# 17                                           52        ...
# 18                                           33        ...
# 19                                            0        ...
#
#     % Single Family                                    Geography_y  \
# 0          0.912439  Census Tract 4001, Alameda County, California
# 1          0.665236  Census Tract 4002, Alameda County, California
# 2          0.478758  Census Tract 4003, Alameda County, California
# 3          0.555446  Census Tract 4004, Alameda County, California
# 4          0.444380  Census Tract 4005, Alameda County, California
# 5          0.632653  Census Tract 4006, Alameda County, California
# 6          0.572421  Census Tract 4007, Alameda County, California
# 7          0.423123  Census Tract 4008, Alameda County, California
# 8          0.492487  Census Tract 4009, Alameda County, California
# 9          0.466443  Census Tract 4010, Alameda County, California
# 10         0.199132  Census Tract 4011, Alameda County, California
# 11         0.538897  Census Tract 4012, Alameda County, California
# 12         0.013445  Census Tract 4013, Alameda County, California
# 13         0.292615  Census Tract 4014, Alameda County, California
# 14         0.531553  Census Tract 4015, Alameda County, California
# 15         0.360000  Census Tract 4016, Alameda County, California
# 16         0.501250  Census Tract 4017, Alameda County, California
# 17         0.372549  Census Tract 4018, Alameda County, California
# 18         0.406250  Census Tract 4019, Alameda County, California
# 19         0.322581  Census Tract 4020, Alameda County, California
#
#     Estimate; Total:  Margin of Error; Total:  Estimate; Owner occupied  \
# 0               1308                      108                      1171
# 1                902                       42                       593
# 2               2626                      132                      1064
# 3               1964                       87                       852
# 4               1686                       82                       738
# 5                701                       71                       330
# 6               1672                      153                       661
# 7               1433                      104                       427
# 8               1095                       87                       480
# 9               2168                      224                       918
# 10              2076                      140                       397
# 11              1352                       84                       632
# 12              1434                      127                       199
# 13              1469                      137                       278
# 14               961                      123                       386
# 15               717                      107                       104
# 16               637                      109                       374
# 17               482                      111                        99
# 18               256                      112                        82
# 19                31                       29                        10
#
#     Margin of Error; Owner occupied  Estimate; Renter occupied  \
# 0                               107                        137
# 1                                71                        309
# 2                               150                       1562
# 3                               133                       1112
# 4                               102                        948
# 5                                76                        371
# 6                               116                       1011
# 7                                90                       1006
# 8                                89                        615
# 9                               185                       1250
# 10                              104                       1679
# 11                              134                        720
# 12                               70                       1235
# 13                              105                       1191
# 14                              111                        575
# 15                               64                        613
# 16                              112                        263
# 17                               57                        383
# 18                               48                        174
# 19                               16                         21
#
#    Margin of Error; Renter occupied  % Renter Occupied  % Owner Occupied
# 0                                74           0.104740          0.895260
# 1                                73           0.342572          0.657428
# 2                               182           0.594821          0.405179
# 3                               152           0.566191          0.433809
# 4                               119           0.562278          0.437722
# 5                               101           0.529244          0.470756
# 6                               166           0.604665          0.395335
# 7                               119           0.702024          0.297976
# 8                               110           0.561644          0.438356
# 9                               256           0.576568          0.423432
# 10                              159           0.808767          0.191233
# 11                              142           0.532544          0.467456
# 12                              137           0.861227          0.138773
# 13                              160           0.810756          0.189244
# 14                              130           0.598335          0.401665
# 15                              110           0.854951          0.145049
# 16                               88           0.412873          0.587127
# 17                              113           0.794606          0.205394
# 18                              110           0.679688          0.320312
# 19                               33           0.677419          0.322581
#
# [20 rows x 56 columns]

# %%
merged.columns
merged = merged[['Id2','Percent of population 25 years and over with Bachelor\'s degree', 
      'All families - Percent  below poverty level; Estimate; Families', 
      '% Single Family', '% Owner Occupied', 'Percent NH White alone',
       'Percent NH Black or African African alone', 'Percent NH Asian alone',
       'Percent Hispanic', 'Estimate; Total Number of Housing Units', 'Estimate; Median value (dollars)', 
        'Median income (dollars); All households']]
merged_rename = merged.rename({'All families - Percent  below poverty level; Estimate; Families': "% below poverty level",
              'Estimate; Total Number of Housing Units': 'Total number of housing units',
              'Estimate; Median value (dollars)': "Median home value",
              'Median income (dollars); All households': "Median income", 'Id2': "Geoid"}, axis=1)
#print("num tracts", len(merged))
      
merged_rename.head(50)
# Out:
#          Geoid  \
# 0   6001400100
# 1   6001400200
# 2   6001400300
# 3   6001400400
# 4   6001400500
# 5   6001400600
# 6   6001400700
# 7   6001400800
# 8   6001400900
# 9   6001401000
# 10  6001401100
# 11  6001401200
# 12  6001401300
# 13  6001401400
# 14  6001401500
# 15  6001401600
# 16  6001401700
# 17  6001401800
# 18  6001401900
# 19  6001402000
# 20  6001402100
# 21  6001402200
# 22  6001402300
# 23  6001402400
# 24  6001402500
# 25  6001402600
# 26  6001402700
# 27  6001402800
# 28  6001402900
# 29  6001403000
# 30  6001403100
# 31  6001403200
# 32  6001403300
# 33  6001403400
# 34  6001403500
# 35  6001403600
# 36  6001403700
# 37  6001403800
# 38  6001403900
# 39  6001404000
# 40  6001404100
# 41  6001404200
# 42  6001404300
# 43  6001404400
# 44  6001404501
# 45  6001404502
# 46  6001404600
# 47  6001404700
# 48  6001404800
# 49  6001404900
#
#     Percent of population 25 years and over with Bachelor's degree  \
# 0                                                34.5
# 1                                                37.6
# 2                                                32.1
# 3                                                44.0
# 4                                                28.1
# 5                                                51.9
# 6                                                19.4
# 7                                                33.5
# 8                                                28.2
# 9                                                19.0
# 10                                               38.8
# 11                                               36.7
# 12                                               24.7
# 13                                                9.3
# 14                                               14.3
# 15                                               12.5
# 16                                               17.1
# 17                                               11.2
# 18                                               25.1
# 19                                                0.0
# 20                                                6.3
# 21                                               22.9
# 22                                               17.3
# 23                                               21.8
# 24                                                9.6
# 25                                               40.1
# 26                                                9.9
# 27                                               20.4
# 28                                               26.3
# 29                                               15.4
# 30                                               15.3
# 31                                                0.0
# 32                                               25.7
# 33                                               26.1
# 34                                               32.4
# 35                                               36.0
# 36                                               41.3
# 37                                               41.4
# 38                                               29.9
# 39                                               33.0
# 40                                               45.4
# 41                                               34.0
# 42                                               32.7
# 43                                               38.3
# 44                                               35.1
# 45                                               40.0
# 46                                               32.7
# 47                                               32.6
# 48                                               27.9
# 49                                               29.9
#
#     % below poverty level  % Single Family  % Owner Occupied  \
# 0                     3.1         0.912439          0.895260
# 1                     0.0         0.665236          0.657428
# 2                     6.9         0.478758          0.405179
# 3                     4.0         0.555446          0.433809
# 4                     6.0         0.444380          0.437722
# 5                    26.4         0.632653          0.470756
# 6                     8.1         0.572421          0.395335
# 7                    21.7         0.423123          0.297976
# 8                     4.0         0.492487          0.438356
# 9                    31.7         0.466443          0.423432
# 10                   25.2         0.199132          0.191233
# 11                    7.1         0.538897          0.467456
# 12                   35.7         0.013445          0.138773
# 13                   25.7         0.292615          0.189244
# 14                   16.8         0.531553          0.401665
# 15                   19.6         0.360000          0.145049
# 16                   32.7         0.501250          0.587127
# 17                   48.9         0.372549          0.205394
# 18                    6.0         0.406250          0.320312
# 19                  100.0         0.322581          0.322581
# 20                   41.0         0.396456          0.043641
# 21                   37.1         0.387056          0.236641
# 22                    0.0         0.315068          0.136986
# 23                   25.4         0.287375          0.273256
# 24                   30.0         0.168689          0.172808
# 25                   15.3         0.088424          0.294444
# 26                   21.1         0.300380          0.327189
# 27                   64.8         0.000000          0.066208
# 28                   25.8         0.000000          0.019659
# 29                   18.7         0.032797          0.242775
# 30                   41.0         0.020221          0.408000
# 31                    0.0         0.725000          1.000000
# 32                   16.3         0.081946          0.223140
# 33                    1.5         0.015112          0.146284
# 34                   19.4         0.108314          0.186550
# 35                    1.8         0.082506          0.186785
# 36                    5.2         0.009898          0.171354
# 37                    0.0         0.307297          0.335503
# 38                    5.7         0.195141          0.414079
# 39                    3.3         0.118229          0.230726
# 40                    3.9         0.231640          0.246667
# 41                    0.0         0.825768          0.836538
# 42                    0.0         0.788911          0.888336
# 43                    1.1         0.762590          0.845278
# 44                    2.7         0.941176          0.890278
# 45                    2.1         0.932322          0.854808
# 46                    0.8         0.990394          0.964894
# 47                    0.0         0.952218          0.868080
# 48                    0.0         0.511710          0.539740
# 49                    1.4         0.770283          0.626948
#
#     Percent NH White alone  Percent NH Black or African African alone  \
# 0                 0.769150                                   0.041435
# 1                 0.767823                                   0.022640
# 2                 0.714142                                   0.099114
# 3                 0.698082                                   0.092588
# 4                 0.419526                                   0.346635
# 5                 0.338305                                   0.473150
# 6                 0.356832                                   0.453986
# 7                 0.326789                                   0.378702
# 8                 0.376453                                   0.545182
# 9                 0.166775                                   0.566320
# 10                0.522670                                   0.140242
# 11                0.672763                                   0.138767
# 12                0.222392                                   0.418783
# 13                0.078903                                   0.500566
# 14                0.098275                                   0.636582
# 15                0.048327                                   0.584882
# 16                0.132800                                   0.318400
# 17                0.113043                                   0.652174
# 18                0.169617                                   0.028024
# 19                0.000000                                   0.241379
# 20                0.100922                                   0.568638
# 21                0.168305                                   0.393869
# 22                0.416149                                   0.062112
# 23                0.231702                                   0.579021
# 24                0.082464                                   0.769668
# 25                0.157689                                   0.258570
# 26                0.019048                                   0.753016
# 27                0.202242                                   0.485380
# 28                0.152195                                   0.278049
# 29                0.028267                                   0.015158
# 30                0.163505                                   0.259259
# 31                1.000000                                   0.000000
# 32                0.261678                                   0.054576
# 33                0.346852                                   0.226254
# 34                0.394595                                   0.245483
# 35                0.281924                                   0.446842
# 36                0.547019                                   0.222495
# 37                0.583354                                   0.077797
# 38                0.607170                                   0.217926
# 39                0.605949                                   0.178780
# 40                0.689692                                   0.047644
# 41                0.725588                                   0.042941
# 42                0.773226                                   0.037993
# 43                0.705322                                   0.032362
# 44                0.774049                                   0.060962
# 45                0.733387                                   0.048666
# 46                0.741383                                   0.111343
# 47                0.733302                                   0.091126
# 48                0.363510                                   0.301184
# 49                0.570825                                   0.061374
#
#     Percent NH Asian alone  Percent Hispanic  Total number of housing units  \
# 0                 0.110724          0.007312                           1439
# 1                 0.069364          0.106936                            932
# 2                 0.075544          0.085214                           2801
# 3                 0.078143          0.062988                           2020
# 4                 0.066241          0.115988                           1735
# 5                 0.032220          0.059666                            784
# 6                 0.095104          0.049218                           2016
# 7                 0.174709          0.086190                           1678
# 8                 0.007499          0.041245                           1198
# 9                 0.143205          0.071196                           2682
# 10                0.110391          0.173191                           2305
# 11                0.116103          0.058449                           1414
# 12                0.165800          0.167329                           1785
# 13                0.197681          0.185520                           1801
# 14                0.100682          0.107100                           1236
# 15                0.180297          0.104089                            900
# 16                0.069867          0.425067                            800
# 17                0.079051          0.144664                            816
# 18                0.109145          0.541298                            256
# 19                0.000000          0.758621                             31
# 20                0.200760          0.109604                            903
# 21                0.062464          0.312898                            788
# 22                0.027950          0.493789                            146
# 23                0.103030          0.065268                           1204
# 24                0.093365          0.041232                            824
# 25                0.529873          0.053869                            622
# 26                0.041905          0.179048                            789
# 27                0.178363          0.071637                           1385
# 28                0.508293          0.045854                            902
# 29                0.919295          0.028677                           1555
# 30                0.461608          0.042457                            544
# 31                0.000000          0.000000                             40
# 32                0.624166          0.041468                           2282
# 33                0.316329          0.077054                           3044
# 34                0.196647          0.056650                           3813
# 35                0.121164          0.050089                           2921
# 36                0.108789          0.044458                           3536
# 37                0.120030          0.170906                           2138
# 38                0.065557          0.057106                           2511
# 39                0.120515          0.052745                           1920
# 40                0.145058          0.079171                           3799
# 41                0.083529          0.076765                           1498
# 42                0.105373          0.043930                           1497
# 43                0.178353          0.026429                           2502
# 44                0.111857          0.000000                            748
# 45                0.096200          0.041229                           2704
# 46                0.089409          0.019428                           1978
# 47                0.083492          0.066317                            879
# 48                0.191156          0.134401                           1409
# 49                0.211252          0.095842                           2046
#
#     Median home value  Median income
# 0           1000000.0       186439.0
# 1            909500.0       122647.0
# 2            718100.0        66638.0
# 3            790500.0        80391.0
# 4            572000.0        50658.0
# 5            586700.0        39802.0
# 6            511600.0        32471.0
# 7            499100.0        37750.0
# 8            524600.0        51767.0
# 9            415600.0        36875.0
# 10           553600.0        39495.0
# 11           589200.0        55592.0
# 12           367800.0        25833.0
# 13           409300.0        22785.0
# 14           365600.0        27188.0
# 15           511900.0        35439.0
# 16           436400.0        52853.0
# 17           423700.0        25043.0
# 18           355000.0        48750.0
# 19                NaN         6845.0
# 20           506900.0        20574.0
# 21           510800.0        28355.0
# 22           490900.0        42167.0
# 23           462000.0        20767.0
# 24           327200.0        32847.0
# 25           437900.0        28021.0
# 26           455500.0        32882.0
# 27           358700.0        12246.0
# 28                NaN        20347.0
# 29           374100.0        17365.0
# 30           447500.0        22452.0
# 31           495200.0       107727.0
# 32           437500.0        51500.0
# 33           474800.0        46463.0
# 34           419000.0        40357.0
# 35           390800.0        53427.0
# 36           427600.0        60368.0
# 37           729300.0        74721.0
# 38           464100.0        76383.0
# 39           377200.0        60616.0
# 40           692000.0        55755.0
# 41           903000.0       133452.0
# 42          1000000.0       182778.0
# 43           876400.0       117214.0
# 44           961600.0       157813.0
# 45           861100.0       120439.0
# 46           844200.0       132672.0
# 47           791900.0       133844.0
# 48           675600.0        67266.0
# 49           603100.0        69741.0

# %% [markdown]
# #### Get only Bay Area counties

# %%
county_codes = ['6001', '6013', '6041', '6055', '6075', '6081', '6085', '6097', '6095']

# %%
merged_bay = merged[merged["Id2"].apply(lambda x: str(x)[:4]).isin(county_codes)]
print("num tracts", len(merged_bay))
merged_bay.head()
# Out:
# num tracts 1405
#           Id2  Percent of population 25 years and over with Bachelor's degree  \
# 0  6001400100                                               34.5
# 1  6001400200                                               37.6
# 2  6001400300                                               32.1
# 3  6001400400                                               44.0
# 4  6001400500                                               28.1
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                0.0
# 2                                                6.9
# 3                                                4.0
# 4                                                6.0
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.665236          0.657428                0.767823
# 2         0.478758          0.405179                0.714142
# 3         0.555446          0.433809                0.698082
# 4         0.444380          0.437722                0.419526
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.022640                0.069364
# 2                                   0.099114                0.075544
# 3                                   0.092588                0.078143
# 4                                   0.346635                0.066241
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0          0.007312                                     1439
# 1          0.106936                                      932
# 2          0.085214                                     2801
# 3          0.062988                                     2020
# 4          0.115988                                     1735
#
#    Estimate; Median value (dollars)  Median income (dollars); All households
# 0                         1000000.0                                 186439.0
# 1                          909500.0                                 122647.0
# 2                          718100.0                                  66638.0
# 3                          790500.0                                  80391.0
# 4                          572000.0                                  50658.0

# %% [markdown]
# #### Missing demog data exploration

# %%
print("number of tracts in the bay area:", len(merged_bay))
print("number of bay tracts with complete demographic info:", len(merged_bay.dropna())) 
print("percent of tracts that have at least one nan entry: ", (len(merged_bay)-len(merged_bay.dropna()))/len(merged_bay)) 

#by column
for col in merged_bay.columns[1:]:
    column = merged_bay[col]
    num_missing = len(column) - len(column.dropna())
    print(col, ", num missing:", num_missing)
# Out:
# number of tracts in the bay area: 1405
# number of bay tracts with complete demographic info: 1382
# percent of tracts that have at least one nan entry:  0.016370106761565837
# Percent of population 25 years and over with Bachelor's degree , num missing: 2
# All families - Percent  below poverty level; Estimate; Families , num missing: 4
# % Single Family , num missing: 3
# % Owner Occupied , num missing: 3
# Percent NH White alone , num missing: 2
# Percent NH Black or African African alone , num missing: 2
# Percent NH Asian alone , num missing: 2
# Percent Hispanic , num missing: 2
# Estimate; Total Number of Housing Units , num missing: 0
# Estimate; Median value (dollars) , num missing: 23
# Median income (dollars); All households , num missing: 5

# %%
na_free = merged_bay.dropna()
only_na = merged_bay[~merged_bay.index.isin(na_free.index)]

#this is the dataframe of the census tracts that have at least one null value in their demographic variables, 
#merged with the ACS 2009 population estimates. There doesn't seem to be a connection between CTs with very 
#small populations and those with missing values, though the largest problem seems to be coming from the % poverty level
#column
pop_df = pd.read_csv(demog_data_path+"ACS_09_5YR_B01003_totalpop.csv")

na_ct_pop = pd.merge(only_na, pop_df, how='inner', right_on='Id2', left_on='Id2')
na_ct_pop
# Out:
#            Id2  \
# 0   6001402000
# 1   6001402900
# 2   6001420400
# 3   6001422600
# 4   6001422800
# 5   6001427500
# 6   6013316000
# 7   6041122000
# 8   6055200900
# 9   6075011500
# 10  6075012000
# 11  6075017902
# 12  6075033201
# 13  6075033202
# 14  6075060100
# 15  6081603500
# 16  6081604300
# 17  6085504700
# 18  6085511605
# 19  6085511606
# 20  6085511607
# 21  6095252800
# 22  6095253000
#
#     Percent of population 25 years and over with Bachelor's degree  \
# 0                                                 0.0
# 1                                                26.3
# 2                                                27.4
# 3                                                 0.0
# 4                                                48.4
# 5                                                11.9
# 6                                                 8.0
# 7                                                 1.9
# 8                                                 2.6
# 9                                                 3.9
# 10                                               37.2
# 11                                               28.4
# 12                                               24.6
# 13                                               32.6
# 14                                               61.3
# 15                                                NaN
# 16                                                NaN
# 17                                                0.0
# 18                                               57.9
# 19                                               37.9
# 20                                               40.7
# 21                                               19.1
# 22                                                2.6
#
#     All families - Percent  below poverty level; Estimate; Families  \
# 0                                               100.0
# 1                                                25.8
# 2                                                19.1
# 3                                               100.0
# 4                                                 4.6
# 5                                                43.7
# 6                                                 0.0
# 7                                                 0.0
# 8                                                 NaN
# 9                                                12.3
# 10                                               28.2
# 11                                               22.3
# 12                                                0.0
# 13                                               10.7
# 14                                                4.4
# 15                                                NaN
# 16                                                NaN
# 17                                                0.0
# 18                                                0.0
# 19                                               11.2
# 20                                                0.0
# 21                                               12.3
# 22                                                NaN
#
#     % Single Family  % Owner Occupied  Percent NH White alone  \
# 0          0.322581          0.322581                0.000000
# 1          0.000000          0.019659                0.152195
# 2          0.115760          0.011412                0.244402
# 3          0.375000          0.000000                0.261097
# 4          0.056929          0.005795                0.347013
# 5          0.272727          0.000000                0.160035
# 6          0.117530          0.065104                0.523708
# 7          1.000000          0.000000                0.297371
# 8          1.000000          0.000000                0.582878
# 9          0.054962          0.015656                0.186287
# 10         0.020455          0.010782                0.503377
# 11         0.192519          0.017107                0.445059
# 12         0.061518          0.000000                0.463104
# 13         0.112733          0.006387                0.413138
# 14         0.329485          0.016968                0.811572
# 15              NaN               NaN                     NaN
# 16              NaN               NaN                     NaN
# 17         0.133333          0.000000                1.000000
# 18         0.075000          0.000000                0.511895
# 19         0.062791          0.000000                0.411644
# 20         0.106918          0.000000                0.477543
# 21         0.765957          0.022265                0.627378
# 22              NaN               NaN                0.289140
#
#     Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                    0.241379                0.000000
# 1                                    0.278049                0.508293
# 2                                    0.045260                0.494998
# 3                                    0.000000                0.447346
# 4                                    0.024140                0.418527
# 5                                    0.421751                0.128205
# 6                                    0.162774                0.040340
# 7                                    0.322514                0.044800
# 8                                    0.214936                0.082574
# 9                                    0.031048                0.733506
# 10                                   0.029369                0.333040
# 11                                   0.154941                0.158893
# 12                                   0.124810                0.265411
# 13                                   0.083669                0.333501
# 14                                   0.015226                0.061287
# 15                                        NaN                     NaN
# 16                                        NaN                     NaN
# 17                                   0.000000                0.000000
# 18                                   0.045340                0.182480
# 19                                   0.020205                0.368493
# 20                                   0.103038                0.268824
# 21                                   0.103066                0.046512
# 22                                   0.410907                0.024918
#
#     Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0           0.758621                                       31
# 1           0.045854                                      902
# 2           0.178180                                      717
# 3           0.158399                                       24
# 4           0.162794                                     1335
# 5           0.145889                                      308
# 6           0.222222                                      502
# 7           0.238857                                       12
# 8           0.087432                                        8
# 9           0.010349                                      655
# 10          0.082526                                     2591
# 11          0.216206                                      909
# 12          0.107501                                      764
# 13          0.131888                                     2945
# 14          0.036163                                     1126
# 15               NaN                                        0
# 16               NaN                                        0
# 17          0.000000                                       75
# 18          0.163728                                      240
# 19          0.110274                                     1720
# 20          0.083884                                      477
# 21          0.146934                                     2021
# 22          0.212663                                        0
#
#     Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                                NaN                                   6845.0
# 1                                NaN                                  20347.0
# 2                                NaN                                  31825.0
# 3                                NaN                                   5833.0
# 4                                NaN                                  16429.0
# 5                                NaN                                  35726.0
# 6                                NaN                                  21458.0
# 7                                NaN                                      NaN
# 8                                NaN                                      NaN
# 9                                NaN                                  14397.0
# 10                               NaN                                  34923.0
# 11                               NaN                                  57969.0
# 12                               NaN                                  43702.0
# 13                               NaN                                  52151.0
# 14                               NaN                                 113235.0
# 15                               NaN                                      NaN
# 16                               NaN                                      NaN
# 17                               NaN                                 151250.0
# 18                               NaN                                  58750.0
# 19                               NaN                                  30670.0
# 20                               NaN                                  29088.0
# 21                               NaN                                  52974.0
# 22                               NaN                                      NaN
#
#                                             Geography  Estimate; Total  \
# 0       Census Tract 4020, Alameda County, California               87
# 1       Census Tract 4029, Alameda County, California             1025
# 2       Census Tract 4204, Alameda County, California             2099
# 3       Census Tract 4226, Alameda County, California             1149
# 4       Census Tract 4228, Alameda County, California             6628
# 5       Census Tract 4275, Alameda County, California             1131
# 6   Census Tract 3160, Contra Costa County, Califo...             1413
# 7         Census Tract 1220, Marin County, California             4375
# 8          Census Tract 2009, Napa County, California             1647
# 9   Census Tract 115, San Francisco County, Califo...              773
# 10  Census Tract 120, San Francisco County, Califo...             3405
# 11  Census Tract 179.02, San Francisco County, Cal...             2530
# 12  Census Tract 332.01, San Francisco County, Cal...             3293
# 13  Census Tract 332.02, San Francisco County, Cal...             5952
# 14  Census Tract 601, San Francisco County, Califo...             2627
# 15    Census Tract 6035, San Mateo County, California                0
# 16    Census Tract 6043, San Mateo County, California                0
# 17  Census Tract 5047, Santa Clara County, California              151
# 18  Census Tract 5116.05, Santa Clara County, Cali...             3573
# 19  Census Tract 5116.06, Santa Clara County, Cali...             2920
# 20  Census Tract 5116.07, Santa Clara County, Cali...             1514
# 21       Census Tract 2528, Solano County, California             3784
# 22       Census Tract 2530, Solano County, California             6381
#
#     Margin of Error; Total
# 0                       69
# 1                      163
# 2                      308
# 3                      612
# 4                     1184
# 5                      251
# 6                      341
# 7                      233
# 8                      799
# 9                       97
# 10                     350
# 11                     394
# 12                     558
# 13                     725
# 14                     468
# 15                     132
# 16                     132
# 17                     187
# 18                    1215
# 19                     392
# 20                     282
# 21                     491
# 22                     320

# %% [markdown]
# #### Merge Demographic features with neighbors dataframe to contribute CRA eligibility information by tract and exclude CTs without oppositely coded neighbors
#
# Universe: all of the CTs in the 9 county bay area that had loan activity have oppositely coded neighbors. The boolean_tracts_all_2009.csv file includes all the tracts that have oppositely coded neighbors and their CRA eligibility.

# %%
data_path = '/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/neighbors/'
cra_elig_neighbors = pd.read_csv(data_path+ 'boolean_tracts_all_2009.csv')
cra_elig_neighbors.head()
# Out:
#         Tract  Year  CRA Eligible
# 0  6001433700  2009      eligible
# 1  6001435101  2009  not eligible
# 2  6001435101  2009  not eligible
# 3  6001435101  2009  not eligible
# 4  6001435101  2009  not eligible

# %%
demog_with_cra = pd.merge(merged, cra_elig_neighbors, how='right', left_on='Id2', right_on='Tract')
#.drop("Id2", axis=1) 
#i think that this is supposed to
#be a right merge because the demographics dataframe has all the census tracts, while the boolean neighbors one only
#has the census tracts in the bay area that have neighbors
demog_with_cra = demog_with_cra.drop(["Tract", "Year"], axis=1)
print(len(demog_with_cra))
demog_with_cra.head()
# Out:
# 1228
#           Id2  Percent of population 25 years and over with Bachelor's degree  \
# 0  6001400100                                               34.5
# 1  6001400300                                               32.1
# 2  6001400400                                               44.0
# 3  6001400500                                               28.1
# 4  6001400600                                               51.9
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                6.9
# 2                                                4.0
# 3                                                6.0
# 4                                               26.4
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.478758          0.405179                0.714142
# 2         0.555446          0.433809                0.698082
# 3         0.444380          0.437722                0.419526
# 4         0.632653          0.470756                0.338305
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.099114                0.075544
# 2                                   0.092588                0.078143
# 3                                   0.346635                0.066241
# 4                                   0.473150                0.032220
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0          0.007312                                     1439
# 1          0.085214                                     2801
# 2          0.062988                                     2020
# 3          0.115988                                     1735
# 4          0.059666                                      784
#
#    Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                         1000000.0                                 186439.0
# 1                          718100.0                                  66638.0
# 2                          790500.0                                  80391.0
# 3                          572000.0                                  50658.0
# 4                          586700.0                                  39802.0
#
#    CRA Eligible
# 0  not eligible
# 1  not eligible
# 2  not eligible
# 3      eligible
# 4      eligible

# %% [markdown]
# #### Get total number and percentages of loans data from HMDA files
# This is currently for 2009, but next step is to do it for the average of the recovery period 2013-2017
#
#
# Universe: all of the CTs in the 9 county bay area that had loan activity during 2009

# %%
filepath = '/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/parsed_data/'
Alameda = pd.read_csv(filepath+'Alameda_2009_parsed.csv')
Alameda["Geoid"] = Alameda["Tract"].apply(lambda x: int(x*100 + 6001000000))

ContraCosta = pd.read_csv(filepath+'ContraCosta_2009_parsed.csv')
ContraCosta["Geoid"] = ContraCosta["Tract"].apply(lambda x: int(x*100 + 6013000000))

Napa = pd.read_csv(filepath+'Napa_2009_parsed.csv')
Napa["Geoid"] = Napa["Tract"].apply(lambda x: int(x*100 + 6055000000))

Marin = pd.read_csv(filepath+'Marin_2009_parsed.csv')
Marin["Geoid"] = Marin["Tract"].apply(lambda x: int(x*100 + 6041000000))

SanMateo = pd.read_csv(filepath+'SanMateo_2009_parsed.csv')
SanMateo["Geoid"] = SanMateo["Tract"].apply(lambda x: int(x*100 + 6081000000))

SanFrancisco = pd.read_csv(filepath+'SanFrancisco_2009_parsed.csv')
SanFrancisco["Geoid"] = SanFrancisco["Tract"].apply(lambda x: int(x*100 + 6075000000))

Solano = pd.read_csv(filepath+'Solano_2009_parsed.csv')
Solano["Geoid"] = Solano["Tract"].apply(lambda x: int(x*100 + 6095000000))

SantaClara = pd.read_csv(filepath+'SantaClara_2009_parsed.csv')
SantaClara["Geoid"] = SantaClara["Tract"].apply(lambda x: int(x*100 + 6085000000))

Sonoma = pd.read_csv(filepath+'Sonoma_2009_parsed.csv')
Sonoma["Geoid"] = Sonoma["Tract"].apply(lambda x: int(x*100 + 6097000000))

counties = [Alameda, ContraCosta, Napa, Marin, SanMateo, SanFrancisco,Solano,SantaClara, Sonoma]

bay_counties_loans = pd.concat(counties).reset_index(drop=True)
bay_counties_loans["Total Loans"] = bay_counties_loans['# HI borrower, LI tract'] + bay_counties_loans['# HI borrower, HI tract']+ bay_counties_loans['# LI borrower, LI tract']
+ bay_counties_loans['# LI borrower, HI tract']
bay_counties_loans = bay_counties_loans.drop(["Tract", "Year"], axis=1)

# %% [markdown]
# #### Merge Loans Data with cra_demog features

# %%
allvars_2009 = pd.merge(demog_with_cra, bay_counties_loans, how="left", left_on='Id2', right_on='Geoid').drop(['CRA Eligible_y', "Geoid"], axis=1)
allvars_2009['CRA'] = allvars_2009['CRA Eligible_x'].apply(lambda x: 1 if x == 'eligible' else 0)
allvars_2009.to_csv("/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/regression/all_vars2009.csv")
print(allvars_2009.columns)
allvars_2009.head()
# Out:
# Index(['Id2', 'Percent of population 25 years and over with Bachelor's degree',
#        'All families - Percent  below poverty level; Estimate; Families',
#        '% Single Family', '% Owner Occupied', 'Percent NH White alone',
#        'Percent NH Black or African African alone', 'Percent NH Asian alone',
#        'Percent Hispanic', 'Estimate; Total Number of Housing Units',
#        'Estimate; Median value (dollars)',
#        'Median income (dollars); All households', 'CRA Eligible_x', 'County',
#        'type', '% HI borrower, LI tract', '# HI borrower, LI tract',
#        '% HI borrower, HI tract', '# HI borrower, HI tract',
#        '% LI borrower, LI tract', '# LI borrower, LI tract',
#        '%LI borrower, HI tract', '# LI borrower, HI tract', 'Total Loans',
#        'CRA'],
#       dtype='object')
#           Id2  Percent of population 25 years and over with Bachelor's degree  \
# 0  6001400100                                               34.5
# 1  6001400300                                               32.1
# 2  6001400400                                               44.0
# 3  6001400500                                               28.1
# 4  6001400600                                               51.9
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                6.9
# 2                                                4.0
# 3                                                6.0
# 4                                               26.4
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.478758          0.405179                0.714142
# 2         0.555446          0.433809                0.698082
# 3         0.444380          0.437722                0.419526
# 4         0.632653          0.470756                0.338305
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.099114                0.075544
# 2                                   0.092588                0.078143
# 3                                   0.346635                0.066241
# 4                                   0.473150                0.032220
#
#    Percent Hispanic  Estimate; Total Number of Housing Units ...   \
# 0          0.007312                                     1439 ...
# 1          0.085214                                     2801 ...
# 2          0.062988                                     2020 ...
# 3          0.115988                                     1735 ...
# 4          0.059666                                      784 ...
#
#    % HI borrower, LI tract  # HI borrower, LI tract % HI borrower, HI tract  \
# 0                 0.000000                      0.0                0.981818
# 1                 0.000000                      0.0                0.906250
# 2                 0.000000                      0.0                0.979167
# 3                 0.877193                     50.0                0.000000
# 4                 0.870968                     27.0                0.000000
#
#   # HI borrower, HI tract % LI borrower, LI tract  # LI borrower, LI tract  \
# 0                    54.0                0.000000                      0.0
# 1                    58.0                0.000000                      0.0
# 2                    47.0                0.000000                      0.0
# 3                     0.0                0.122807                      7.0
# 4                     0.0                0.129032                      4.0
#
#    %LI borrower, HI tract  # LI borrower, HI tract  Total Loans  CRA
# 0                0.018182                      1.0         54.0    0
# 1                0.093750                      6.0         58.0    0
# 2                0.020833                      1.0         47.0    0
# 3                0.000000                      0.0         57.0    1
# 4                0.000000                      0.0         31.0    1
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Regression Data Prep

# %%
allvars_2009.columns
noinc = ['% HI borrower, LI tract',
       '# HI borrower, LI tract', '% HI borrower, HI tract',
       '# HI borrower, HI tract', '% LI borrower, LI tract',
       '# LI borrower, LI tract', '%LI borrower, HI tract',
       '# LI borrower, HI tract', 'Geoid', 'Total Loans', "CRA Eligible_x", "type", "County", "Id2"]

X_vars = allvars_2009.loc[:, ~allvars_2009.columns.isin(noinc)]
y = allvars_2009["Total Loans"]
print(len(y))
print(len(X_vars))
X_vars.head()
# Out:
# 1228
# 1228
#    Percent of population 25 years and over with Bachelor's degree  \
# 0                                               34.5
# 1                                               32.1
# 2                                               44.0
# 3                                               28.1
# 4                                               51.9
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                6.9
# 2                                                4.0
# 3                                                6.0
# 4                                               26.4
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.478758          0.405179                0.714142
# 2         0.555446          0.433809                0.698082
# 3         0.444380          0.437722                0.419526
# 4         0.632653          0.470756                0.338305
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.099114                0.075544
# 2                                   0.092588                0.078143
# 3                                   0.346635                0.066241
# 4                                   0.473150                0.032220
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0          0.007312                                     1439
# 1          0.085214                                     2801
# 2          0.062988                                     2020
# 3          0.115988                                     1735
# 4          0.059666                                      784
#
#    Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                         1000000.0                                 186439.0
# 1                          718100.0                                  66638.0
# 2                          790500.0                                  80391.0
# 3                          572000.0                                  50658.0
# 4                          586700.0                                  39802.0
#
#    CRA
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1

# %%
# This is the number of nans (missing data) 
# for col in X_vars.columns:
#     num = sum(np.isnan(X_vars[col]))
#     print(col, num)

# %% [markdown]
# #### Some of the data is Nan, I dealt with this is 3 ways, discuss the best strategy for this with Carolina

# %% [markdown]
# Strategy 1: drop all the Nans, lose ~1.5% of the data

# %%
#need to concatenate x with y, dropna and then unconcatenate in order to do this correctly
xydf = X_vars.copy()
xydf["y"] = y
dropped = xydf.dropna()

X_drop = dropped.loc[:, dropped.columns != 'y']
y_drop = dropped['y']

print("num tracts", len(X_drop))
print("y", len(y_drop))

print("before drop", len(xydf))
print("pct lost", (len(xydf) - len(X_drop))/len(xydf))
# Out:
# num tracts 1210
# y 1210
# before drop 1228
# pct lost 0.014657980456026058

# %% [markdown]
# Strategy 2: infill nans with mean of column

# %%
X_vars_mean = X_vars.fillna(X_vars.mean())
y_mean = y.fillna(y.mean())
print("num tracts", len(X_vars))
print("num y", len(y))
X_vars_mean.head()
# Out:
# num tracts 1228
# num y 1228
#    Percent of population 25 years and over with Bachelor's degree  \
# 0                                               34.5
# 1                                               32.1
# 2                                               44.0
# 3                                               28.1
# 4                                               51.9
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                6.9
# 2                                                4.0
# 3                                                6.0
# 4                                               26.4
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.478758          0.405179                0.714142
# 2         0.555446          0.433809                0.698082
# 3         0.444380          0.437722                0.419526
# 4         0.632653          0.470756                0.338305
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.099114                0.075544
# 2                                   0.092588                0.078143
# 3                                   0.346635                0.066241
# 4                                   0.473150                0.032220
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0          0.007312                                     1439
# 1          0.085214                                     2801
# 2          0.062988                                     2020
# 3          0.115988                                     1735
# 4          0.059666                                      784
#
#    Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                         1000000.0                                 186439.0
# 1                          718100.0                                  66638.0
# 2                          790500.0                                  80391.0
# 3                          572000.0                                  50658.0
# 4                          586700.0                                  39802.0
#
#    CRA
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1

# %% [markdown]
# Strategy 3: infill nans with median of column

# %%
X_vars_med = X_vars.fillna(X_vars.median())

y_med = y.fillna(y.median())
print("X", len(X_vars_med))
print("y", len(y_med))

X_vars_med.head()
# Out:
# X 1228
# y 1228
#    Percent of population 25 years and over with Bachelor's degree  \
# 0                                               34.5
# 1                                               32.1
# 2                                               44.0
# 3                                               28.1
# 4                                               51.9
#
#    All families - Percent  below poverty level; Estimate; Families  \
# 0                                                3.1
# 1                                                6.9
# 2                                                4.0
# 3                                                6.0
# 4                                               26.4
#
#    % Single Family  % Owner Occupied  Percent NH White alone  \
# 0         0.912439          0.895260                0.769150
# 1         0.478758          0.405179                0.714142
# 2         0.555446          0.433809                0.698082
# 3         0.444380          0.437722                0.419526
# 4         0.632653          0.470756                0.338305
#
#    Percent NH Black or African African alone  Percent NH Asian alone  \
# 0                                   0.041435                0.110724
# 1                                   0.099114                0.075544
# 2                                   0.092588                0.078143
# 3                                   0.346635                0.066241
# 4                                   0.473150                0.032220
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0          0.007312                                     1439
# 1          0.085214                                     2801
# 2          0.062988                                     2020
# 3          0.115988                                     1735
# 4          0.059666                                      784
#
#    Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                         1000000.0                                 186439.0
# 1                          718100.0                                  66638.0
# 2                          790500.0                                  80391.0
# 3                          572000.0                                  50658.0
# 4                          586700.0                                  39802.0
#
#    CRA
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1

# %% [markdown]
# #### Data Normalization

# %%
def normalize_columns(data, mean_df, std_df):
    '''
    Input:
      data (data frame): contains only numeric columns
    Output:
      data frame, the same data, except each column is standardized 
      to have 0-mean and unit variance
    '''
    normalized_data=(data-mean_df.mean())/std_df.std()

    return normalized_data

# %%
def unnormalize_columns(data, mean_df, std_df):
    unnormalized_data=(data*std_df.std())+mean_df.mean()

    return unnormalized_data

# %% [markdown]
# #### Regression Using dropped NaNs method

# %%
import statsmodels.api as sm
from statsmodels.base.model import GenericLikelihoodModel

# %%
#normalize the data before perfoming the regression
normal_x_drop = normalize_columns(X_drop, X_drop, X_drop)
normal_y_drop = normalize_columns(y_drop, y_drop, y_drop)

# %%
from sklearn import linear_model
sk_model = linear_model.LinearRegression()
sk_model.fit(normal_x_drop,normal_y_drop)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X_drop_constant = sm.add_constant(normal_x_drop)
sm_model = sm.regression.linear_model.OLS(normal_y_drop, X_drop_constant)
results = sm_model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.626
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     167.1
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):          1.09e-245
# Time:                        12:41:45   Log-Likelihood:                -1121.1
# No. Observations:                1210   AIC:                             2268.
# Df Residuals:                    1197   BIC:                             2334.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================================================
#                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------
# const                                                            2.776e-17      0.018   1.57e-15      1.000      -0.035       0.035
# Percent of population 25 years and over with Bachelor's degree      0.0114      0.033      0.342      0.732      -0.054       0.077
# All families - Percent  below poverty level; Estimate; Families     0.0165      0.026      0.644      0.520      -0.034       0.067
# % Single Family                                                     0.1256      0.038      3.346      0.001       0.052       0.199
# % Owner Occupied                                                    0.2006      0.041      4.840      0.000       0.119       0.282
# Percent NH White alone                                             -0.4324      0.154     -2.799      0.005      -0.735      -0.129
# Percent NH Black or African African alone                          -0.1532      0.081     -1.885      0.060      -0.313       0.006
# Percent NH Asian alone                                             -0.2824      0.112     -2.516      0.012      -0.503      -0.062
# Percent Hispanic                                                   -0.2002      0.121     -1.656      0.098      -0.437       0.037
# Estimate; Total Number of Housing Units                             0.7333      0.018     39.957      0.000       0.697       0.769
# Estimate; Median value (dollars)                                   -0.0737      0.028     -2.599      0.009      -0.129      -0.018
# Median income (dollars); All households                             0.1774      0.032      5.548      0.000       0.115       0.240
# CRA                                                                 0.2512      0.024     10.414      0.000       0.204       0.299
# ==============================================================================
# Omnibus:                      736.631   Durbin-Watson:                   0.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10191.972
# Skew:                           2.574   Prob(JB):                         0.00
# Kurtosis:                      16.253   Cond. No.                         27.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
with open('/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/results/prelim_regression_results_droppednana.html', 'w') as outfile:
    outfile.write(results.summary().as_html())

# %% [markdown]
# #### This is the scikitlearn output, which is redundant with the statsmodels output above.

# %%
# from collections import OrderedDict
# linear_coef_dict = {}
# for linear_coef, linear_feature in zip(sk_model.coef_, X_vars.columns):
#     linear_coef_dict[linear_feature] = linear_coef
    
# sorted_coefs_linear = OrderedDict(sorted(linear_coef_dict.items(), key=lambda t: t[1]))
# sorted_coefs_linear

# %% [markdown]
# #### Regression using filled means method

# %%
normal_x_vars_mean = normalize_columns(X_vars_mean, X_vars_mean, X_vars_mean)
normal_y_mean = normalize_columns(y_mean, y_mean, y_mean)

# %%
from sklearn import linear_model
sk_model_mean = linear_model.LinearRegression()
sk_model_mean.fit(normal_x_vars_mean,normal_y_mean)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X_mean_constant = sm.add_constant(normal_x_vars_mean)
sm_model = sm.regression.linear_model.OLS(normal_y_mean, X_mean_constant)
results = sm_model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Total Loans   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     161.4
# Date:                Tue, 15 Jan 2019   Prob (F-statistic):          1.89e-241
# Time:                        23:35:47   Log-Likelihood:                -1156.6
# No. Observations:                1228   AIC:                             2339.
# Df Residuals:                    1215   BIC:                             2406.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===========================================================================================================================================================
#                                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                    3.031e-15      0.018    1.7e-13      1.000      -0.035       0.035
# Percent of population 25 years and over with Bachelor's degree                             -0.0096      0.031     -0.307      0.759      -0.071       0.052
# Percent below poverty level; Estimate; Population for whom poverty status is determined     0.0268      0.023      1.173      0.241      -0.018       0.072
# % Single Family                                                                             0.1132      0.037      3.026      0.003       0.040       0.187
# % Owner Occupied                                                                            0.1898      0.040      4.716      0.000       0.111       0.269
# Percent White alone                                                                        -0.4907      0.156     -3.154      0.002      -0.796      -0.185
# Percent Black or African African alone                                                     -0.1769      0.082     -2.170      0.030      -0.337      -0.017
# Percent Asian alone                                                                        -0.3260      0.113     -2.882      0.004      -0.548      -0.104
# Percent Hispanic                                                                           -0.2461      0.122     -2.025      0.043      -0.485      -0.008
# Estimate; Total Number of Housing Units                                                     0.7199      0.018     39.095      0.000       0.684       0.756
# Estimate; Median value (dollars)                                                           -0.0670      0.028     -2.401      0.016      -0.122      -0.012
# Median income (dollars); All households                                                     0.1964      0.030      6.578      0.000       0.138       0.255
# CRA                                                                                         0.2328      0.024      9.625      0.000       0.185       0.280
# ==============================================================================
# Omnibus:                      752.737   Durbin-Watson:                   0.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10192.505
# Skew:                           2.610   Prob(JB):                         0.00
# Kurtosis:                      16.113   Cond. No.                         26.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# with open('regression_results.html', 'w') as outfile:
#     outfile.write(results.summary().as_html())

# %%
# from collections import OrderedDict
# linear_coef_dict = {}
# for linear_coef, linear_feature in zip(sk_model_mean.coef_, X_vars.columns):
#     linear_coef_dict[linear_feature] = linear_coef
    
# sorted_coefs_linear_mean = OrderedDict(sorted(linear_coef_dict.items(), key=lambda t: t[1]))
# sorted_coefs_linear_mean

# %% [markdown]
# #### Regression using filled medians method

# %%
normal_x_median = normalize_columns(X_vars_med, X_vars_med, X_vars_med)
normal_y_median = normalize_columns(y_med, y_med, y_med)
normal_x_median.head()
# Out:
#    Percent of population 25 years and over with Bachelor's degree  \
# 0                                           1.289540
# 1                                           1.048455
# 2                                           2.243834
# 3                                           0.646647
# 4                                           3.037404
#
#    Percent below poverty level; Estimate; Population for whom poverty status is determined  \
# 0                                          -1.024133
# 1                                          -0.559209
# 2                                          -0.319702
# 3                                          -0.291525
# 4                                          -0.080195
#
#    % Single Family  % Owner Occupied  Percent White alone  \
# 0         1.089326          1.527403             1.516134
# 1        -0.543388         -0.720945             1.274925
# 2        -0.254675         -0.589601             1.204503
# 3        -0.672811         -0.571645            -0.016946
# 4         0.035994         -0.420097            -0.373095
#
#    Percent Black or African African alone  Percent Asian alone  \
# 0                               -0.360677            -0.507372
# 1                                0.143072            -0.719931
# 2                                0.086081            -0.704224
# 3                                2.304835            -0.776139
# 4                                3.409778            -0.981697
#
#    Percent Hispanic  Estimate; Total Number of Housing Units  \
# 0         -1.401598                                -0.538142
# 1         -0.964692                                 0.671644
# 2         -1.089341                                -0.022073
# 3         -0.792095                                -0.275222
# 4         -1.107975                                -1.119940
#
#    Estimate; Median value (dollars)  Median income (dollars); All households  \
# 0                          2.274438                                 4.727079
# 1                          0.761496                                -0.131244
# 2                          1.150063                                 0.426485
# 3                         -0.022614                                -0.779286
# 4                          0.056280                                -1.219532
#
#         CRA
# 0 -0.753568
# 1 -0.753568
# 2 -0.753568
# 3  1.325940
# 4  1.325940

# %%
from sklearn import linear_model
sk_model_med = linear_model.LinearRegression()
sk_model_med.fit(normal_x_median,normal_y_median)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
normal_x_median_constant = sm.add_constant(normal_x_median)
sm_model = sm.regression.linear_model.OLS(normal_y_median, normal_x_median_constant)
results = sm_model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Total Loans   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.614
# Method:                 Least Squares   F-statistic:                     163.7
# Date:                Tue, 15 Jan 2019   Prob (F-statistic):          9.78e-244
# Time:                        23:35:47   Log-Likelihood:                -1151.3
# No. Observations:                1228   AIC:                             2329.
# Df Residuals:                    1215   BIC:                             2395.
# Df Model:                          12
# Covariance Type:            nonrobust
# ===========================================================================================================================================================
#                                                                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                                   -5.399e-17      0.018  -3.05e-15      1.000      -0.035       0.035
# Percent of population 25 years and over with Bachelor's degree                             -0.0106      0.031     -0.340      0.734      -0.072       0.050
# Percent below poverty level; Estimate; Population for whom poverty status is determined     0.0248      0.023      1.085      0.278      -0.020       0.070
# % Single Family                                                                             0.1131      0.037      3.040      0.002       0.040       0.186
# % Owner Occupied                                                                            0.1927      0.040      4.822      0.000       0.114       0.271
# Percent White alone                                                                        -0.5142      0.153     -3.357      0.001      -0.815      -0.214
# Percent Black or African African alone                                                     -0.1899      0.080     -2.365      0.018      -0.347      -0.032
# Percent Asian alone                                                                        -0.3428      0.111     -3.078      0.002      -0.561      -0.124
# Percent Hispanic                                                                           -0.2650      0.120     -2.214      0.027      -0.500      -0.030
# Estimate; Total Number of Housing Units                                                     0.7229      0.018     39.384      0.000       0.687       0.759
# Estimate; Median value (dollars)                                                           -0.0672      0.028     -2.423      0.016      -0.122      -0.013
# Median income (dollars); All households                                                     0.1954      0.030      6.572      0.000       0.137       0.254
# CRA                                                                                         0.2357      0.024      9.784      0.000       0.188       0.283
# ==============================================================================
# Omnibus:                      752.804   Durbin-Watson:                   0.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10326.732
# Skew:                           2.605   Prob(JB):                         0.00
# Kurtosis:                      16.217   Cond. No.                         26.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# from collections import OrderedDict
# linear_coef_dict = {}
# for linear_coef, linear_feature in zip(sk_model_med.coef_, X_vars.columns):
#     linear_coef_dict[linear_feature] = linear_coef
    
# sorted_coefs_linear_med = OrderedDict(sorted(linear_coef_dict.items(), key=lambda t: t[1]))
# sorted_coefs_linear_med
