# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.base.model import GenericLikelihoodModel
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# #### 2013-2014

# %%
demog_with_cra_dummies1314 = pd.read_csv("/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/regression/demog_with_cra_dummies_201314.csv")

# %%
X_vars_models_1314 = demog_with_cra_dummies1314.loc[:, ~demog_with_cra_dummies1314.columns.isin(['Geoid', "Geoid_x","Geoid_y", "_merge", 'Total Loans',
         'type', "CRA Eligible", 'Year', "Year_x", "Tract_y", '% HI borrower, LI tract',
       '# HI borrower, LI tract', '% HI borrower, HI tract',
       '# HI borrower, HI tract', '% LI borrower, LI tract',
       '# LI borrower, LI tract', '%LI borrower, HI tract',
       '# LI borrower, HI tract' ])]
Y_vars_models_1314 = demog_with_cra_dummies1314['Total Loans']

# %%
X_1314_constant = sm.add_constant(X_vars_models_1314)[['Percent NH White alone',"Total number of housing units", '% Single Family',
    '% Owner Occupied','Median home value','Median income',
    'Percent of population 25 years and over with Bachelor\'s degree',
    '% below poverty level', "County_Alameda County", "County_Contra Costa County", "County_Marin County", 
          "County_San Francisco County", "County_San Mateo County", "County_Santa Clara County",
              "County_Solano County", "County_Sonoma County", "CRA"]]
m = sm.regression.linear_model.OLS(Y_vars_models_1314, X_1314_constant)
results_m = m.fit()
print(results_m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Total Loans   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     115.9
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):          5.68e-205
# Time:                        16:35:52   Log-Likelihood:                -4318.1
# No. Observations:                 842   AIC:                             8670.
# Df Residuals:                     825   BIC:                             8751.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Percent NH White alone                                           -12.2547     10.290     -1.191      0.234     -32.451       7.942
# Total number of housing units                                      0.0303      0.002     12.573      0.000       0.026       0.035
# % Single Family                                                    7.9845     11.997      0.666      0.506     -15.564      31.533
# % Owner Occupied                                                  52.2943     15.576      3.357      0.001      21.722      82.867
# Median home value                                              -4.068e-05   1.46e-05     -2.787      0.005   -6.93e-05    -1.2e-05
# Median income                                                      0.0001      0.000      1.009      0.313      -0.000       0.000
# Percent of population 25 years and over with Bachelor's degree    39.6984     25.897      1.533      0.126     -11.134      90.531
# % below poverty level                                             -0.2667      0.255     -1.045      0.296      -0.768       0.234
# County_Alameda County                                            -16.6609      9.493     -1.755      0.080     -35.295       1.973
# County_Contra Costa County                                       -13.0434     10.178     -1.282      0.200     -33.021       6.934
# County_Marin County                                              -10.3522     14.349     -0.721      0.471     -38.516      17.812
# County_San Francisco County                                      -27.0241     11.099     -2.435      0.015     -48.809      -5.239
# County_San Mateo County                                          -25.3488     10.458     -2.424      0.016     -45.877      -4.820
# County_Santa Clara County                                         -7.5468      9.421     -0.801      0.423     -26.040      10.946
# County_Solano County                                              -8.8303     10.446     -0.845      0.398     -29.335      11.674
# County_Sonoma County                                             -84.0167     11.414     -7.361      0.000    -106.420     -61.613
# CRA                                                                6.6794      3.852      1.734      0.083      -0.882      14.241
# ==============================================================================
# Omnibus:                     1085.527   Durbin-Watson:                   0.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           189397.753
# Skew:                           6.604   Prob(JB):                         0.00
# Kurtosis:                      75.278   Cond. No.                     1.27e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/ameliabaum/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
vif = pd.DataFrame()
no_counties = X_vars_models_1314.loc[:, ~X_vars_models_1314.columns.isin(["County_Alameda County", "County_Contra Costa County", "County_Marin County", 
          "County_San Francisco County", "County_San Mateo County", "County_Santa Clara County",
              "County_Solano County", "County_Sonoma County"])]
vif["VIF Factor new model 3.05"] = [variance_inflation_factor(no_counties.values, i) for i in range(no_counties.shape[1])]
vif["features"] = no_counties.columns
vif.round(2)
# vif.to_csv("/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/results/collinearity/VIF_newmodel3.5_201314.csv")
vif
# Out:
#     VIF Factor new model 3.05  \
# 0                   22.851035
# 1                    4.499467
# 2                   27.428819
# 3                   41.900341
# 4                   20.687833
# 5                    3.037654
# 6                    7.627228
# 7                    8.826826
# 8                   10.264679
# 9                   30.189172
# 10                  28.437601
# 11                   3.324346
# 12                   1.055524
#
#                                              features
# 0   Percent of population 25 years and over with B...
# 1                               % below poverty level
# 2                                     % Single Family
# 3                                    % Owner Occupied
# 4                              Percent NH White alone
# 5           Percent NH Black or African African alone
# 6                              Percent NH Asian alone
# 7                                    Percent Hispanic
# 8                       Total number of housing units
# 9                                   Median home value
# 10                                      Median income
# 11                                                CRA
# 12                                 County_Napa County

# %% [markdown]
# #### 2015 - 2017

# %%
demog_with_cra_dummies151617 = pd.read_csv("/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/data/regression/demog_with_cra_dummies_20151617.csv")

# %%
X_vars_models_151617 = demog_with_cra_dummies151617.loc[:, ~demog_with_cra_dummies151617.columns.isin(['Geoid', "Geoid_x","Geoid_y", "_merge", 'Total Loans',
         'type', "CRA Eligible", 'Year', "Year_x", "Tract_y", '% HI borrower, LI tract',
       '# HI borrower, LI tract', '% HI borrower, HI tract',
       '# HI borrower, HI tract', '% LI borrower, LI tract',
       '# LI borrower, LI tract', '%LI borrower, HI tract',
       '# LI borrower, HI tract' ])]
Y_vars_models_151617 = demog_with_cra_dummies151617['Total Loans']

# %%
X_151617_constant = sm.add_constant(X_vars_models_151617)[['Percent NH White alone',"Total number of housing units", '% Single Family',
    '% Owner Occupied','Median home value','Median income',
    'Percent of population 25 years and over with Bachelor\'s degree',
    '% below poverty level', "County_Alameda County", "County_Contra Costa County", "County_Marin County", 
          "County_San Francisco County", "County_San Mateo County", "County_Santa Clara County",
              "County_Solano County", "County_Sonoma County", "CRA"]]
m = sm.regression.linear_model.OLS(Y_vars_models_151617, X_vars_models_151617)
results_m = m.fit()
print(results_m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Total Loans   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     29.96
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):           1.07e-86
# Time:                        16:51:22   Log-Likelihood:                -4296.6
# No. Observations:                 841   AIC:                             8637.
# Df Residuals:                     819   BIC:                             8741.
# Df Model:                          21
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Unnamed: 0                                                         0.0299      0.020      1.481      0.139      -0.010       0.069
# Percent of population 25 years and over with Bachelor's degree    39.8653     28.828      1.383      0.167     -16.720      96.451
# % below poverty level                                              0.2720      0.269      1.010      0.313      -0.257       0.801
# % Single Family                                                   -5.9063     12.009     -0.492      0.623     -29.478      17.665
# % Owner Occupied                                                  69.4407     15.996      4.341      0.000      38.043     100.838
# Percent NH White alone                                          -131.5920     62.920     -2.091      0.037    -255.095      -8.089
# Percent NH Black or African African alone                       -116.9859     63.992     -1.828      0.068    -242.593       8.622
# Percent NH Asian alone                                          -123.5244     61.961     -1.994      0.047    -245.145      -1.904
# Percent Hispanic                                                -103.2971     61.122     -1.690      0.091    -223.271      16.677
# Total number of housing units                                      0.0396      0.002     16.049      0.000       0.035       0.044
# Median home value                                              -5.023e-05   1.48e-05     -3.404      0.001   -7.92e-05   -2.13e-05
# Median income                                                      0.0002      0.000      1.618      0.106    -3.7e-05       0.000
# CRA                                                                1.3095      4.105      0.319      0.750      -6.749       9.368
# County_Alameda County                                             81.0062     58.881      1.376      0.169     -34.569     196.581
# County_Contra Costa County                                        90.4847     60.303      1.500      0.134     -27.883     208.852
# County_Marin County                                              -14.4369     89.693     -0.161      0.872    -190.493     161.619
# County_Napa County                                                -9.7545     93.587     -0.104      0.917    -193.454     173.945
# County_San Francisco County                                      -93.7199    129.998     -0.721      0.471    -348.889     161.450
# County_San Mateo County                                         -106.3883    135.274     -0.786      0.432    -371.913     159.136
# County_Santa Clara County                                        -97.2802    141.317     -0.688      0.491    -374.667     180.106
# County_Solano County                                             -75.9152    147.122     -0.516      0.606    -364.696     212.866
# County_Sonoma County                                            -191.9747    149.189     -1.287      0.199    -484.813     100.863
# ==============================================================================
# Omnibus:                      633.977   Durbin-Watson:                   1.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11599.717
# Skew:                           3.297   Prob(JB):                         0.00
# Kurtosis:                      19.957   Cond. No.                     1.57e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
vif = pd.DataFrame()
no_counties_151617 = X_vars_models_151617.loc[:, ~X_vars_models_151617.columns.isin(["County_Alameda County", "County_Contra Costa County", "County_Marin County", 
          "County_San Francisco County", "County_San Mateo County", "County_Santa Clara County",
              "County_Solano County", "County_Sonoma County"])]
vif["VIF Factor new model 3.05"] = [variance_inflation_factor(no_counties_151617.values, i) for i in range(no_counties_151617.shape[1])]
vif["features"] = no_counties_151617.columns
vif.round(2)
vif.to_csv("/Users/ameliabaum/Desktop/Amelia/CRA_Thesis/communityreinvestmentact/results/collinearity/VIF_newmodel3.5_20151617.csv")
vif
# Out:
#     VIF Factor new model 3.05  \
# 0                    5.574027
# 1                   23.208129
# 2                    4.511682
# 3                   27.580886
# 4                   41.916135
# 5                   21.173842
# 6                    3.156526
# 7                    8.047049
# 8                    9.415637
# 9                   10.288388
# 10                  30.494357
# 11                  29.087089
# 12                   3.320478
# 13                   1.060020
#
#                                              features
# 0                                          Unnamed: 0
# 1   Percent of population 25 years and over with B...
# 2                               % below poverty level
# 3                                     % Single Family
# 4                                    % Owner Occupied
# 5                              Percent NH White alone
# 6           Percent NH Black or African African alone
# 7                              Percent NH Asian alone
# 8                                    Percent Hispanic
# 9                       Total number of housing units
# 10                                  Median home value
# 11                                      Median income
# 12                                                CRA
# 13                                 County_Napa County
